# %% [markdown]
# # Linear Regression

# %%
#retrieve the train and test set from data-preprocessing.ipynb
# %store -r

# %%
# %run plot-functions.ipynb

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
train_prediction = linear_model.predict(X_train)
mse = mean_squared_error(y_train, train_prediction)
rmse = np.sqrt(mean_squared_error(y_train, train_prediction))
r2 = r2_score(y_train, train_prediction)
print("Model performance on the training set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the training set:
# Mean squared error: 0.031008163047158414, Root mean squared error: 0.176091348586915 and R2 score: 0.46867787434587804

# %%
test_prediction = linear_model.predict(X_test)
mse = mean_squared_error(y_test, test_prediction)
rmse = np.sqrt(mean_squared_error(y_test, test_prediction))
r2 = r2_score(y_test, test_prediction)
print("Model performance on the test set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the test set:
# Mean squared error: 0.03167502603609767, Root mean squared error: 0.17797479045105705 and R2 score: 0.4157096877656594

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(2, figsize = (15, 12))
ax[0].scatter(y_train, train_prediction)
ax[0].set_xlabel("actual values of y (training dataset)")
ax[0].set_ylabel("predicted values of y (training dataset)")

ax[1].scatter(y_test, test_prediction)
ax[1].set_xlabel("actual values of y (test dataset)")
ax[1].set_ylabel("predicted values of y (test dataset)")
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_train["bmi"], X_train["s5"], y_train)
ax.scatter3D(X_train["bmi"], X_train["s5"], train_prediction)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_test["bmi"], X_test["s5"], y_test)
ax.scatter3D(X_test["bmi"], X_test["s5"], test_prediction)
plt.show()

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_features = PolynomialFeatures(degree = 2)
X_train_poly = poly_features.fit_transform(X_train)
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
train_prediction = poly_model.predict(X_train_poly)

# %%
test_prediction = poly_model.predict(poly_features.fit_transform(X_test))

# %%
mse = mean_squared_error(y_train, train_prediction)
rmse = np.sqrt(mean_squared_error(y_train, train_prediction))
r2 = r2_score(y_train, train_prediction)
print("Model performance on the training set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the training set:
# Mean squared error: 0.030712562379283, Root mean squared error: 0.1752499996555863 and R2 score: 0.47374296559173745

# %%
mse = mean_squared_error(y_test, test_prediction)
rmse = np.sqrt(mean_squared_error(y_test, test_prediction))
r2 = r2_score(y_test, test_prediction)
print("Model performance on the test set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the test set:
# Mean squared error: 0.03128568179837214, Root mean squared error: 0.17687758987043029 and R2 score: 0.4228916886886591

# %%
fig, ax = plt.subplots(2, figsize = (15, 12))
ax[0].scatter(y_train, train_prediction)
ax[0].set_xlabel("actual values of y (training dataset)")
ax[0].set_ylabel("predicted values of y (training dataset)")

ax[1].scatter(y_test, test_prediction)
ax[1].set_xlabel("actual values of y (test dataset)")
ax[1].set_ylabel("predicted values of y (test dataset)")
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_train["bmi"], X_train["s5"], y_train)
ax.scatter3D(X_train["bmi"], X_train["s5"], train_prediction)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_test["bmi"], X_test["s5"], y_test)
ax.scatter3D(X_test["bmi"], X_test["s5"], test_prediction)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfmodel = RandomForestRegressor(random_state = 9)
y_train = y_train.stack()
rfmodel.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=9)

# %%
train_prediction = rfmodel.predict(X_train)

# %%
mse = mean_squared_error(y_train, train_prediction)
rmse = np.sqrt(mean_squared_error(y_train, train_prediction))
r2 = r2_score(y_train, train_prediction)
print("Model performance on the training set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the training set:
# Mean squared error: 0.005478380659530095, Root mean squared error: 0.07401608378947169 and R2 score: 0.9061284329311244

# %%
test_prediction = rfmodel.predict(X_test)

# %%
mse = mean_squared_error(y_test, test_prediction)
rmse = np.sqrt(mean_squared_error(y_test, test_prediction))
r2 = r2_score(y_test, test_prediction)
print("Model performance on the test set:")
print(f"Mean squared error: {mse}, Root mean squared error: {rmse} and R2 score: {r2}")
# Out:
# Model performance on the test set:
# Mean squared error: 0.03835374047308732, Root mean squared error: 0.1958411102733216 and R2 score: 0.2925114261678471

# %%
fig, ax = plt.subplots(2, figsize = (15, 12))
ax[0].scatter(y_train, train_prediction)
ax[0].set_xlabel("actual values of y (training dataset)")
ax[0].set_ylabel("predicted values of y (training dataset)")

ax[1].scatter(y_test, test_prediction)
ax[1].set_xlabel("actual values of y (test dataset)")
ax[1].set_ylabel("predicted values of y (test dataset)")
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_train["bmi"], X_train["s5"], y_train)
ax.scatter3D(X_train["bmi"], X_train["s5"], train_prediction)
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection = "3d")
ax.scatter3D(X_test["bmi"], X_test["s5"], y_test)
ax.scatter3D(X_test["bmi"], X_test["s5"], test_prediction)
plt.show()
